# %%
import pandas as pd

# %%
df = pd.read_excel("HDR 2007-2008 Table 27KoneNath.xlsx")
df
# Out:
#      HDI_rank Human_developpement_level        country  \
# 0           1                     HIGH         Iceland
# 1           2                     HIGH          Norway
# 2           3                     HIGH       Australia
# 3           4                     HIGH          Canada
# 4           5                     HIGH         Ireland
# ..        ...                       ...            ...
# 172       173                       LOW           Mali
# 173       174                       LOW          Niger
# 174       175                       LOW  Guinea-Bissau
# 175       176                       LOW   Burkina Faso
# 176       177                       LOW   Sierra Leone
#
#      Intentional_homicides_per_100000_people_2004  \
# 0                                             1.0
# 1                                             0.8
# 2                                             1.3
# 3                                             1.9
# ...

# %%
df.to_csv('HDR 2007-2008 Table 27.csv',index=False)
