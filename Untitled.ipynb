# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("HDR 2007-2008 Table 15.xlsx")
df.head(12)
# Out:
#                                   Unnamed: 0  \
# 0                                        NaN
# 1   15  Inequality in income and expenditure
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                  HDI rank
# 11                                       NaN
#
#                                  Unnamed: 1 Unnamed: 2  \
# 0                                       NaN        NaN
# 1                                       NaN        NaN
# 2                                       NaN        NaN
# 3                                       NaN        NaN
# 4   15. Inequality in income or expenditure        NaN
# ...

# %%
df.tail(30)
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 193                               Developing countries        NaN        NaN
# 194                          Least developed countries        NaN        NaN
# 195                                        Arab States        NaN        NaN
# 196                          East Asia and the Pacific        NaN        NaN
# 197                    Latin America and the Caribbean        NaN        NaN
# 198                                         South Asia        NaN        NaN
# 199                                 Sub-Saharan Africa        NaN        NaN
# 200             Central and Eastern Europe and the CIS        NaN        NaN
# 201                                               OECD        NaN        NaN
# 202                                   High-income OECD        NaN        NaN
# 203                                                NaN        NaN        NaN
# ...

# %%
df = pd.read_excel("HDR 2007-2008 Table 15.xlsx", header=9)
df = df.dropna(how="all", axis=1)
df = df.dropna(how="all", axis=0).reset_index(drop=True)
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0                HDI rank        NaN        NaN  Survey year        NaN
# 1                     NaN        NaN        NaN          NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN        NaN          NaN        NaN
# 3                       1    Iceland        NaN           ..        NaN
# 4                       2     Norway        NaN         2000          c
#
#   Share of income or expenditure\n(%)    Unnamed: 7   Unnamed: 9  Unnamed: 11  \
# 0                          Poorest 10%  Poorest 20%  Richest 20%  Richest 10%
# 1                                  NaN          NaN          NaN          NaN
# 2                                  NaN          NaN          NaN          NaN
# 3                                   ..           ..           ..           ..
# 4                                  3.9          9.6         37.2         23.4
#
# ...

# %%
df.tail(30)
# Out:
#                                             Unnamed: 0  \
# 173                                                169
# 174                                                170
# 175                                                171
# 176                                                172
# 177                                                173
# 178                                                174
# 179                                                175
# 180                                                176
# 181                                                177
# 182                               Developing countries
# 183                          Least developed countries
# 184                                        Arab States
# 185                          East Asia and the Pacific
# 186                    Latin America and the Caribbean
# 187                                         South Asia
# 188                                 Sub-Saharan Africa
# ...

# %%
df.columns #nous permet de connaitre tous les éléments qui sont dans les colonnes
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Share of income or expenditure\n(%) ', 'Unnamed: 7', 'Unnamed: 9',
#        'Unnamed: 11', 'Richest 10% to poorest 10%', 'Unnamed: 14',
#        'Richest 20% to poorest 20%', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df = df.drop(np.arange(182,len(df)), axis=0).reset_index(drop=True)

# %%
len(df) #nous permet d'avoir le nombre d'éléments (longueur) dans un objet
# Out:
# 182

# %%
np.arange(182,len(df)) #Renvoie des valeurs régulièrement espacées dans un intervalle donné.
# Out:
# array([], dtype=int32)

# %%
np.arange(1,4)
# Out:
# array([1, 2, 3])

# %%
df.tail(25) #Renvoie la liste des 25 derniers éléments de notre dataframe
# Out:
#                 Unnamed: 0                          Unnamed: 1 Unnamed: 2  \
# 157                    154                              Uganda        NaN
# 158                    155                              Gambia        NaN
# 159  LOW HUMAN DEVELOPMENT                                 NaN        NaN
# 160                    156                             Senegal        NaN
# 161                    157                             Eritrea        NaN
# 162                    158                             Nigeria        NaN
# 163                    159       Tanzania (United Republic of)        NaN
# 164                    160                              Guinea        NaN
# 165                    161                              Rwanda        NaN
# 166                    162                              Angola        NaN
# 167                    163                               Benin        NaN
# 168                    164                              Malawi        NaN
# ...

# %%
df = df.dropna(how="all", axis=1)

# %%
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0                HDI rank        NaN        NaN  Survey year        NaN
# 1                     NaN        NaN        NaN          NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN        NaN          NaN        NaN
# 3                       1    Iceland        NaN           ..        NaN
# 4                       2     Norway        NaN         2000          c
#
#   Share of income or expenditure\n(%)    Unnamed: 7   Unnamed: 9  Unnamed: 11  \
# 0                          Poorest 10%  Poorest 20%  Richest 20%  Richest 10%
# 1                                  NaN          NaN          NaN          NaN
# 2                                  NaN          NaN          NaN          NaN
# 3                                   ..           ..           ..           ..
# 4                                  3.9          9.6         37.2         23.4
#
# ...

# %%
columns=['HDI rank',
         'Country',
         'Reference 1',
         'Survey year',
         'Reference 2',
         'Share of income or expenditure Poorest 10%',
         'Share of income or expenditure Poorest 20%',
         'Share of income or expenditureRichest 20%',
         'Share of income or expenditure Richest 10%',
         'Inequality measures Richest 10% to poorest 10%',
         'Reference 3',
         'Inequality measures Richest 20% to poorest 20%',
         'Reference 4',
         'Inequality measures Gini index',    
         'Reference 5'
]

# %%
len(columns)
# Out:
# 15

# %%
len(df.columns)
# Out:
# 15

# %%
df.columns=columns
df.columns
# Out:
# Index(['HDI rank', 'Country', 'Reference 1', 'Survey year', 'Reference 2',
#        'Share of income or expenditure Poorest 10%',
#        'Share of income or expenditure Poorest 20%',
#        'Share of income or expenditureRichest 20%',
#        'Share of income or expenditure Richest 10%',
#        'Inequality measures Richest 10% to poorest 10%', 'Reference 3',
#        'Inequality measures Richest 20% to poorest 20%', 'Reference 4',
#        'Inequality measures Gini index', 'Reference 5'],
#       dtype='object')

# %%
df.head()
# Out:
#                  HDI rank  Country Reference 1  Survey year Reference 2  \
# 0                HDI rank      NaN         NaN  Survey year         NaN
# 1                     NaN      NaN         NaN          NaN         NaN
# 2  HIGH HUMAN DEVELOPMENT      NaN         NaN          NaN         NaN
# 3                       1  Iceland         NaN           ..         NaN
# 4                       2   Norway         NaN         2000           c
#
#   Share of income or expenditure Poorest 10%  \
# 0                                Poorest 10%
# 1                                        NaN
# 2                                        NaN
# 3                                         ..
# 4                                        3.9
#
#   Share of income or expenditure Poorest 20%  \
# 0                                Poorest 20%
# 1                                        NaN
# 2                                        NaN
# 3                                         ..
# ...

# %%
#Supprimer toutes les references qui se trouvent dans notre dataframe
df.drop(['Reference 1','Reference 2','Reference 3','Reference 4','Reference 5'],axis='columns',inplace=True)
df.head()
# Out:
#                  HDI rank  Country  Survey year  \
# 0                HDI rank      NaN  Survey year
# 1                     NaN      NaN          NaN
# 2  HIGH HUMAN DEVELOPMENT      NaN          NaN
# 3                       1  Iceland           ..
# 4                       2   Norway         2000
#
#   Share of income or expenditure Poorest 10%  \
# 0                                Poorest 10%
# 1                                        NaN
# 2                                        NaN
# 3                                         ..
# 4                                        3.9
#
#   Share of income or expenditure Poorest 20%  \
# 0                                Poorest 20%
# 1                                        NaN
# 2                                        NaN
# 3                                         ..
# 4                                        9.6
#
#   Share of income or expenditureRichest 20%  \
# 0                               Richest 20%
# ...

# %%
# Supprimer les lignes qui contenaient les informations dont nous n'avons plus besoin
# et réinitialiser l'index
# np.arange(2) crée un tableau = [0, 1, 2, 3, 4, 5]
df = df.drop(np.arange(0,2), axis=0).reset_index(drop=True)
df.head(20)
# Out:
#                   HDI rank         Country Survey year  \
# 0   HIGH HUMAN DEVELOPMENT             NaN         NaN
# 1                        1         Iceland          ..
# 2                        2          Norway        2000
# 3                        3       Australia        1994
# 4                        4          Canada        2000
# 5                        5         Ireland        2000
# 6                        6          Sweden        2000
# 7                        7     Switzerland        2000
# 8                        8           Japan        1993
# 9                        9     Netherlands        1999
# 10                      10          France        1995
# 11                      11         Finland        2000
# 12                      12   United States        2000
# 13                      13           Spain        2000
# 14                      14         Denmark        1997
# 15                      15         Austria        2000
# ...

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df["HDI rank"].index
df[df["HDI rank"].isin(hdi_categories)].index
# Out:
# Int64Index([0, 71, 157], dtype='int64')

# %%
df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)

# %%
df.loc[:, "HDI rank"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 172    173
# 173    174
# 174    175
# 175    176
# 176    177
# Name: HDI rank, Length: 177, dtype: object

# %%
df.loc[:, "HDI NIVEAU_DEV"] = np.where(df["HDI rank"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] < 71,
                                              "HIGH HUMAN DEVELOPMENT",
                                              "MEDIUM HUMAN DEVELOPMENT"
                                              
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)
df.head()
# Out:
#   HDI rank    Country Survey year Share of income or expenditure Poorest 10%  \
# 0        1    Iceland          ..                                         ..
# 1        2     Norway        2000                                        3.9
# 2        3  Australia        1994                                        2.0
# 3        4     Canada        2000                                        2.6
# 4        5    Ireland        2000                                        2.9
#
#   Share of income or expenditure Poorest 20%  \
# 0                                         ..
# 1                                        9.6
# 2                                        5.9
# 3                                        7.2
# 4                                        7.4
#
#   Share of income or expenditureRichest 20%  \
# 0                                        ..
# 1                                      37.2
# 2                                      41.3
# 3                                      39.9
# ...

# %%
df.tail(30)
# Out:
#     HDI rank                             Country Survey year  \
# 147      148                               Kenya        1997
# 148      149                            Djibouti          ..
# 149      150                         Timor-Leste          ..
# 150      151                            Zimbabwe     1995-96
# 151      152                                Togo          ..
# 152      153                               Yemen        1998
# 153      154                              Uganda        2002
# 154      155                              Gambia        1998
# 155      156                             Senegal        2001
# 156      157                             Eritrea          ..
# 157      158                             Nigeria        2003
# 158      159       Tanzania (United Republic of)     2000-01
# 159      160                              Guinea        2003
# 160      161                              Rwanda        2000
# ...

# %%
#supprimer les ".."
for c in df.columns:
    try:
        df[c] = np.where(df[c] == ".." , "(.)", np.nan, df[c])
    except TypeError:
        pass

# %%
df.tail(20)
# Out:
#     HDI rank                             Country Survey year  \
# 157      158                             Nigeria        2003
# 158      159       Tanzania (United Republic of)     2000-01
# 159      160                              Guinea        2003
# 160      161                              Rwanda        2000
# 161      162                              Angola          ..
# 162      163                               Benin        2003
# 163      164                              Malawi    2004-05
# 164      165                              Zambia        2004
# 165      166                       Côte d'Ivoire        2002
# 166      167                             Burundi        1998
# 167      168  Congo (Democratic Republic of the)          ..
# 168      169                            Ethiopia    1999-00
# 169      170                                Chad          ..
# 170      171            Central African Republic        1993
# ...

# %%
#Exportons notre fichier sur le format CSV
df.to_csv('Gahie.csv',index=False)
