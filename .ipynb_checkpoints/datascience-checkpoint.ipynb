# %%
import numpy as np
import pandas as pd
source = "HDR 2007-2008 Table 14.xlsx"

df = pd.read_excel(source)
df.head(12)
# Out:
#                   Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0                        NaN        NaN         NaN
# 1                        NaN        NaN         NaN
# 2   14  Economic performance        NaN         NaN
# 3                        NaN        NaN         NaN
# 4                        NaN        NaN         NaN
# 5                        NaN        NaN         NaN
# 6                        NaN        NaN         NaN
# 7                   HDI rank        NaN         NaN
# 8     HIGH HUMAN DEVELOPMENT        NaN         NaN
# 9                          1    Iceland         NaN
# 10                         2     Norway         NaN
# 11                         3  Australia         NaN
#
#                                            Unnamed: 3 Unnamed: 4  \
# 0   . . . to have access to the resources needed f...        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 GDP        NaN
# 6                                                 GDP        NaN
# 7                                  US$ billions\n2005        NaN
# 8                                                 NaN        NaN
# 9                                                15.8        NaN
# 10                                              295.5        NaN
# 11                                              732.5        NaN
#
#                  Unnamed: 5 Unnamed: 6      Unnamed: 7 Unnamed: 8  \
# 0                       NaN        NaN             NaN        NaN
# 1                       NaN        NaN             NaN        NaN
# 2                       NaN        NaN             NaN        NaN
# 3                       NaN        NaN             NaN        NaN
# 4                       NaN        NaN  GDP per capita        NaN
# 5                       NaN        NaN             NaN        NaN
# 6                       NaN        NaN             NaN        NaN
# 7    PPP US$ billions\n2005        NaN       US$\n2005        NaN
# 8                       NaN        NaN             NaN        NaN
# 9                      10.8        NaN          53,290        NaN
# 10                    191.5        NaN          63,918        NaN
# 11                    646.3        NaN          36,032        NaN
#
#              Unnamed: 9  ... Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0                   NaN  ...         NaN         NaN         NaN         NaN
# 1                   NaN  ...         NaN         NaN         NaN         NaN
# 2                   NaN  ...         NaN         NaN         NaN         NaN
# 3                   NaN  ...         NaN         NaN         NaN         NaN
# 4                   NaN  ...         NaN         NaN         NaN         NaN
# 5                   NaN  ...         NaN         NaN         NaN         NaN
# 6                   NaN  ...         NaN         NaN         NaN         NaN
# 7   2005 PPP US$a\n2005  ...         NaN         NaN         NaN         NaN
# 8                   NaN  ...         NaN         NaN         NaN         NaN
# 9                36,510  ...         NaN         NaN         NaN         NaN
# 10               41,420  ...         NaN         NaN         NaN         NaN
# 11               31,794  ...         NaN         NaN         NaN         NaN
#
#    Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  Unnamed: 31 Unnamed: 32
# 0          NaN         NaN         NaN         NaN          NaN         NaN
# 1          NaN         NaN         NaN         NaN          NaN         NaN
# 2          NaN         NaN         NaN         NaN          NaN         NaN
# 3          NaN         NaN         NaN         NaN          NaN         NaN
# 4          NaN         NaN         NaN         NaN          NaN         NaN
# 5          NaN         NaN         NaN         NaN          NaN         NaN
# 6          NaN         NaN         NaN         NaN          NaN         NaN
# 7          NaN         NaN         NaN         NaN          NaN         NaN
# 8          NaN         NaN         NaN         NaN          NaN         NaN
# 9          NaN         NaN         NaN         NaN          NaN         NaN
# 10         NaN         NaN         NaN         NaN          NaN         NaN
# 11         NaN         NaN         NaN         NaN          NaN         NaN
#
# [12 rows x 33 columns]

# %%
df = pd.read_excel(source, header = 4)
#suppression des colonnes sans valeurs
df = df.dropna(how = "all", axis = 1)
#suppression des lignes sans valeurs
df = df.dropna(how = "all", axis = 0).reset_index(drop = True)
df.head(20)
# Out:
#                 Unnamed: 0     Unnamed: 1          Unnamed: 3 Unnamed: 4  \
# 0                      NaN            NaN                 NaN        NaN
# 1                      NaN            NaN                 GDP        NaN
# 2                      NaN            NaN                 GDP        NaN
# 3                 HDI rank            NaN  US$ billions\n2005        NaN
# 4   HIGH HUMAN DEVELOPMENT            NaN                 NaN        NaN
# 5                        1        Iceland                15.8        NaN
# 6                        2         Norway               295.5        NaN
# 7                        3      Australia               732.5        NaN
# 8                        4         Canada             1,113.8        NaN
# 9                        5        Ireland               201.8        NaN
# 10                       6         Sweden               357.7        NaN
# 11                       7    Switzerland               367.0        NaN
# 12                       8          Japan             4,534.0        NaN
# 13                       9    Netherlands               624.2        NaN
# 14                      10         France             2,126.6        NaN
# 15                      11        Finland               193.2        NaN
# 16                      12  United States            12,416.5        NaN
# 17                      13          Spain             1,124.6        NaN
# 18                      14        Denmark               258.7        NaN
# 19                      15        Austria               306.1        NaN
#
#                  Unnamed: 5 Unnamed: 6      Unnamed: 7 Unnamed: 8  \
# 0                       NaN        NaN  GDP per capita        NaN
# 1                       NaN        NaN             NaN        NaN
# 2                       NaN        NaN             NaN        NaN
# 3    PPP US$ billions\n2005        NaN       US$\n2005        NaN
# 4                       NaN        NaN             NaN        NaN
# 5                      10.8        NaN          53,290        NaN
# 6                     191.5        NaN          63,918        NaN
# 7                     646.3        NaN          36,032        NaN
# 8                   1,078.0        NaN          34,484        NaN
# 9                     160.1        NaN          48,524        NaN
# 10                    293.5        NaN          39,637        NaN
# 11                    265.0        NaN          49,351        NaN
# 12                  3,995.1        NaN          35,484        NaN
# 13                    533.4        NaN          38,248        NaN
# 14                  1,849.7        NaN          34,936        NaN
# 15                    168.7        NaN          36,820        NaN
# 16                 12,416.5        NaN          41,890        NaN
# 17                  1,179.1        NaN          25,914        NaN
# 18                    184.0        NaN          47,769        NaN
# 19                    277.5        NaN          37,175        NaN
#
#              Unnamed: 9 Unnamed: 10               Unnamed: 11 Unnamed: 12  \
# 0                   NaN         NaN                       NaN         NaN
# 1                   NaN         NaN                       NaN         NaN
# 2                   NaN         NaN  Annual growth rate \n(%)         NaN
# 3   2005 PPP US$a\n2005         NaN               \n1975-2005         NaN
# 4                   NaN         NaN                       NaN         NaN
# 5                36,510         NaN                       1.8         NaN
# 6                41,420         NaN                       2.6         NaN
# 7                31,794         NaN                       2.0         NaN
# 8                33,375         NaN                       1.6         NaN
# 9                38,505         NaN                       4.5         NaN
# 10               32,525         NaN                       1.6         NaN
# 11               35,633         NaN                       1.0         NaN
# 12               31,267         NaN                       2.2         NaN
# 13               32,684         NaN                       1.8         NaN
# 14               30,386         NaN                       1.8         NaN
# 15               32,153         NaN                       2.0         NaN
# 16               41,890         NaN                       2.0         NaN
# 17               27,169         NaN                       2.3         NaN
# 18               33,973         NaN                       1.7         NaN
# 19               33,700         NaN                       2.1         NaN
#
#     Unnamed: 13 Unnamed: 14                                      Unnamed: 15  \
# 0           NaN         NaN                                              NaN
# 1           NaN         NaN  Highest value during \n1975-2005\n2005 PPP US$a
# 2           NaN         NaN                                              NaN
# 3   \n1990-2005         NaN                                              NaN
# 4           NaN         NaN                                              NaN
# 5           2.2         NaN                                           36,510
# 6           2.7         NaN                                           41,420
# 7           2.5         NaN                                           31,794
# 8           2.2         NaN                                           33,375
# 9           6.2         NaN                                           38,505
# 10          2.1         NaN                                           32,525
# 11          0.6         NaN                                           35,633
# 12          0.8         NaN                                           31,267
# 13          1.9         NaN                                           32,684
# 14          1.6         NaN                                           30,386
# 15          2.5         NaN                                           32,153
# 16          2.1         NaN                                           41,890
# 17          2.5         NaN                                           27,169
# 18          1.9         NaN                                           33,973
# 19          1.9         NaN                                           33,700
#
#    Unnamed: 16            Unnamed: 17  \
# 0          NaN                    NaN
# 1          NaN  Year of highest value
# 2          NaN                    NaN
# 3          NaN                    NaN
# 4          NaN                    NaN
# 5          NaN                   2005
# 6          NaN                   2005
# 7          NaN                   2005
# 8          NaN                   2005
# 9          NaN                   2005
# 10         NaN                   2005
# 11         NaN                   2005
# 12         NaN                   2005
# 13         NaN                   2005
# 14         NaN                   2005
# 15         NaN                   2005
# 16         NaN                   2005
# 17         NaN                   2005
# 18         NaN                   2005
# 19         NaN                   2005
#
#                                           Unnamed: 19 Unnamed: 21
# 0    Average annual change in consumer price index...         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                           1990-2005     2004-05
# 4                                                 NaN         NaN
# 5                                                 3.3         4.2
# 6                                                 2.2         1.5
# 7                                                 2.5         2.7
# 8                                                 1.9         2.2
# 9                                                 2.9         2.4
# 10                                                1.6         0.5
# 11                                                1.2         1.2
# 12                                                0.2        -0.3
# 13                                                2.5         1.7
# 14                                                1.6         1.7
# 15                                                1.6         0.9
# 16                                                2.6         3.4
# 17                                                3.4         3.4
# 18                                                2.1         1.8
# 19                                                2.0         2.3

# %%
columns = []
for c in df.columns:
    columns.append([str(v) for v in df[c][:4] if pd.notnull(v)])
columns
# Out:
# [['HDI rank'],
#  [],
#  ['GDP', 'GDP', 'US$ billions\n2005'],
#  [],
#  [' PPP US$ billions\n2005'],
#  [],
#  ['GDP per capita', 'US$\n2005'],
#  [],
#  ['2005 PPP US$a\n2005'],
#  [],
#  ['Annual growth rate \n(%)', '\n1975-2005'],
#  [],
#  ['\n1990-2005'],
#  [],
#  ['Highest value during \n1975-2005\n2005 PPP US$a'],
#  [],
#  ['Year of highest value'],
#  [' Average annual change in consumer price index \n(%)', ' 1990-2005'],
#  ['2004-05']]

# %%
columns = ["HDI rank",
          "Country",
          "GDP - US$ billions 2005",
          "References 1",
          "GDP - PPP US $ billions 2005",
          "References 2",
          "GDP per capita - US$ 2005",
          "References 3",
          "GDP per capita - 2005 PPP US$ 2005",
          "References 4",
          "GDP per capita - Annual growth rate(%) 1975-2005",
          "References 5",
          "GDP per capita - Annual growth rate(%) 1990-2005",
          "References 6",
          "GDP per capita - highest value during 1975-2005 2005 PPP US$",
          "References 7",
          "GDP per capita - year of highest value",
          "Average annual change in consumer price index(%) - 1990-2005",
          "Average annual change in consumer price index(%) - 2004-2005"]

# %%
#réinitialiser les colonnes des cadres de données
df.columns = columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4efcc9723b83> in <module>
#       1 #réinitialiser les colonnes des cadres de données
# ----> 2 df.columns = columns
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 12 elements

# %%
df = df.drop(np.arange(4), axis=0).reset_index(drop=True)
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  HIGH HUMAN DEVELOPMENT        NaN        NaN        NaN        NaN
# 1                       1    Iceland       15.8        NaN       10.8
# 2                       2     Norway      295.5        NaN      191.5
# 3                       3  Australia      732.5        NaN      646.3
# 4                       4     Canada    1,113.8        NaN    1,078.0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN     53,290        NaN     36,510         NaN         1.8
# 2        NaN     63,918        NaN     41,420         NaN         2.6
# 3        NaN     36,032        NaN     31,794         NaN         2.0
# 4        NaN     34,484        NaN     33,375         NaN         1.6
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         2.2         NaN      36,510         NaN        2005
# 2         NaN         2.7         NaN      41,420         NaN        2005
# 3         NaN         2.5         NaN      31,794         NaN        2005
# 4         NaN         2.2         NaN      33,375         NaN        2005
#
#   Unnamed: 19 Unnamed: 21
# 0         NaN         NaN
# 1         3.3         4.2
# 2         2.2         1.5
# 3         2.5         2.7
# 4         1.9         2.2

# %%
df.tail(30)
# Out:
#                                             Unnamed: 0  \
# 170                                                168
# 171                                                169
# 172                                                170
# 173                                                171
# 174                                                172
# 175                                                173
# 176                                                174
# 177                                                175
# 178                                                176
# 179                                                177
# 180                               Developing countries
# 181                          Least developed countries
# 182                                        Arab States
# 183                          East Asia and the Pacific
# 184                    Latin America and the Caribbean
# 185                                         South Asia
# 186                                 Sub-Saharan Africa
# 187             Central and Eastern Europe and the CIS
# 188                                               OECD
# 189                                   High-income OECD
# 190                             High human development
# 191                           Medium human development
# 192                              Low human development
# 193                                        High income
# 194                                      Middle income
# 195                                         Low income
# 196                                              World
# 197                                              NOTES
# 198  a. GDP values expressed in 2005 constant price...
# 199  SOURCES\nColumns 1–4: World Bank 2007b; aggreg...
#
#                              Unnamed: 1 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 170  Congo (Democratic Republic of the)        7.1        NaN       41.1
# 171                            Ethiopia       11.2        NaN       75.1
# 172                                Chad        5.5        NaN       13.9
# 173            Central African Republic        1.4        NaN        4.9
# 174                          Mozambique        6.6        NaN       24.6
# 175                                Mali        5.3        NaN       14.0
# 176                               Niger        3.4        NaN       10.9
# 177                       Guinea-Bissau        0.3        NaN        1.3
# 178                        Burkina Faso        5.2        NaN       16.0
# 179                        Sierra Leone        1.2        NaN        4.5
# 180                                 NaN    9,812.5          T   26,732.3
# 181                                 NaN      306.2          T    1,081.8
# 182                                 NaN    1,043.4          T    1,915.2
# 183                                 NaN    4,122.5          T   12,846.6
# 184                                 NaN    2,469.5          T    4,639.2
# 185                                 NaN    1,206.1          T    5,152.2
# 186                                 NaN      589.9          T    1,395.6
# 187                                 NaN    1,873.0          T    3,827.2
# 188                                 NaN   34,851.2          T   34,076.8
# 189                                 NaN   32,404.5          T   30,711.7
# 190                                 NaN   37,978.4          T   39,633.4
# 191                                 NaN    5,881.2          T   20,312.6
# 192                                 NaN      236.4          T      544.2
# 193                                 NaN   34,338.1          T   32,680.7
# 194                                 NaN    8,552.0          T   22,586.3
# 195                                 NaN    1,416.2          T    5,879.1
# 196                                 NaN   44,155.7          T   60,597.3
# 197                                 NaN        NaN        NaN        NaN
# 198                                 NaN        NaN        NaN        NaN
# 199                                 NaN        NaN        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 170          d        123        NaN        714           d        -4.9
# 171          d        157        NaN      1,055           d        -0.2
# 172          d        561        NaN      1,427           d         0.5
# 173          d        339        NaN      1,224           d        -1.5
# 174          d        335        NaN      1,242           d         2.3
# 175        NaN        392        NaN      1,033         NaN         0.2
# 176          d        244        NaN        781           d        -1.7
# 177          d        190        NaN        827           d        -0.6
# 178          d        391        NaN      1,213           d         0.9
# 179        NaN        216        NaN        806         NaN        -2.1
# 180          T      1,939        NaN      5,282         NaN         2.5
# 181          T        424        NaN      1,499         NaN         0.9
# 182          T      3,659        NaN      6,716         NaN         0.7
# 183          T      2,119        NaN      6,604         NaN         6.1
# 184          T      4,480        NaN      8,417         NaN         0.7
# 185          T        800        NaN      3,416         NaN         2.6
# 186          T        845        NaN      1,998         NaN        -0.5
# 187          T      4,662        NaN      9,527         NaN         1.4
# 188          T     29,860        NaN     29,197         NaN         2.0
# 189          T     35,696        NaN     33,831         NaN         2.1
# 190          T     22,984        NaN     23,986         NaN         1.9
# 191          T      1,412        NaN      4,876         NaN         3.2
# 192          T        483        NaN      1,112         NaN        -0.7
# 193          T     34,759        NaN     33,082         NaN         2.1
# 194          T      2,808        NaN      7,416         NaN         2.1
# 195          T        610        NaN      2,531         NaN         2.2
# 196          T      6,954        NaN      9,543         NaN         1.4
# 197        NaN        NaN        NaN        NaN         NaN         NaN
# 198        NaN        NaN        NaN        NaN         NaN         NaN
# 199        NaN        NaN        NaN        NaN         NaN         NaN
#
#     Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 170         NaN        -5.2         NaN       2,488         NaN        1975
# 171           b         1.5         NaN       1,055           b        2005
# 172         NaN         1.7         NaN       1,427         NaN        2005
# 173         NaN        -0.6         NaN       1,935         NaN        1977
# 174           b         4.3         NaN       1,242           b        2005
# 175         NaN         2.2         NaN       1,033         NaN        2005
# 176         NaN        -0.5         NaN       1,293         NaN        1979
# 177         NaN        -2.6         NaN       1,264         NaN        1997
# 178         NaN         1.3         NaN       1,213         NaN        2005
# 179         NaN        -1.4         NaN       1,111         NaN        1982
# 180         NaN         3.1         NaN          ..         NaN          ..
# 181         NaN         1.8         NaN          ..         NaN          ..
# 182         NaN         2.3         NaN          ..         NaN          ..
# 183         NaN         5.8         NaN          ..         NaN          ..
# 184         NaN         1.2         NaN          ..         NaN          ..
# 185         NaN         3.4         NaN          ..         NaN          ..
# 186         NaN         0.5         NaN          ..         NaN          ..
# 187         NaN         1.4         NaN          ..         NaN          ..
# 188         NaN         1.8         NaN          ..         NaN          ..
# 189         NaN         1.8         NaN          ..         NaN          ..
# 190         NaN         1.8         NaN          ..         NaN          ..
# 191         NaN         4.0         NaN          ..         NaN          ..
# 192         NaN         0.6         NaN          ..         NaN          ..
# 193         NaN         1.8         NaN          ..         NaN          ..
# 194         NaN         3.0         NaN          ..         NaN          ..
# 195         NaN         2.9         NaN          ..         NaN          ..
# 196         NaN         1.5         NaN          ..         NaN          ..
# 197         NaN         NaN         NaN         NaN         NaN         NaN
# 198         NaN         NaN         NaN         NaN         NaN         NaN
# 199         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 19 Unnamed: 21
# 170       424.3        21.3
# 171         4.2        11.6
# 172         5.3         7.9
# 173         3.9         2.9
# 174        22.1         7.2
# 175         3.8         6.4
# 176         4.4         7.8
# 177        20.2         3.3
# 178         4.1         6.4
# 179        19.7        12.1
# 180          ..          ..
# 181          ..          ..
# 182          ..          ..
# 183          ..          ..
# 184          ..          ..
# 185          ..          ..
# 186          ..          ..
# 187          ..          ..
# 188          ..          ..
# 189          ..          ..
# 190          ..          ..
# 191          ..          ..
# 192          ..          ..
# 193          ..          ..
# 194          ..          ..
# 195          ..          ..
# 196          ..          ..
# 197         NaN         NaN
# 198         NaN         NaN
# 199         NaN         NaN

# %%
df = df.drop(np.arange(180,len(df)), axis=0).reset_index(drop=True)

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
df.loc[:, "HDI category"] = np.where(df["HDI rank"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI rank"] > 70,
                                              "MEDIUM HUMAN DEVELOPMENT",
                                              "HIGH HUMAN DEVELOPMENT"
                                             )
                                    )
df.sort_values(by="HDI rank", inplace=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HDI rank'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-746ea517c790> in <module>
#       1 hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
# ----> 2 df = df.drop(df[df["HDI rank"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)
#       3 df.loc[:, "HDI category"] = np.where(df["HDI rank"] > 155,
#       4                                      "LOW HUMAN DEVELOPMENT",
#       5                                      np.where(df["HDI rank"] > 70,
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HDI rank'

# %%
destination = "economic_performance.csv"
# `index=False` signifie que nous n'allons pas garder cette colonne d'index - elle sera recréée lorsque nous ouvrirons le fichier à l'avenir
df.to_csv(destination, index=False)

# %%
df
