# %% [markdown]
# Nous importons un module avec import et pouvons le renommer en utilisant le terme as :
#
# import pandas as pd
#
#
#
# import numpy as np

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Nous commençons par importer le fichier Excel.
#
#
# Dans pandas, une feuille de calcul est appelée dataframe, ou df en abrégé.

# %%
source = ("HDR_2007_2008_Table_27.xlsx")

df = pd.read_excel(source)

df.head(10)
# Out:
#                Unnamed: 0 Unnamed: 1                       Unnamed: 2  \
# 0                     NaN        NaN  … protecting personal security…
# 1    27 Crime and justice        NaN                              NaN
# 2                     NaN        NaN                              NaN
# 3                     NaN        NaN                              NaN
# 4                     NaN        NaN                              NaN
# 5                     NaN        NaN                              NaN
# 6                HDI rank        NaN                              NaN
# 7                     NaN        NaN                              NaN
# 8  HIGH HUMAN DEVELOPMENT        NaN                              NaN
# 9                       1    Iceland                              NaN
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
# 5                                                NaN        NaN
# 6  Intentional homicidesa                 (per 10...        NaN
# 7                                                NaN        NaN
# 8                                                NaN        NaN
# 9                                                  1        NaN
#
#                       Unnamed: 5 Unnamed: 6  \
# 0                            NaN        NaN
# 1                            NaN        NaN
# 2                            NaN        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
# 5                            NaN        NaN
# 6              Prison population        NaN
# 7  Total                   2007d        NaN
# 8                            NaN        NaN
# 9                            119        NaN
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
# 5                                                NaN        NaN
# 6                                                NaN        NaN
# 7  (per 100,000 people)                        2007d        NaN
# 8                                                NaN        NaN
# 9                                                 40        NaN
#
#                                           Unnamed: 9 Unnamed: 10  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
# 5                                                NaN         NaN
# 6                                                NaN         NaN
# 7  Female                         (% of total)   ...         NaN
# 8                                                NaN         NaN
# 9                                                  6         NaN
#
#                                          Unnamed: 11 Unnamed: 12  Unnamed: 13
# 0                                                NaN         NaN          NaN
# 1                                                NaN         NaN          NaN
# 2                                                NaN         NaN          NaN
# 3                                                NaN         NaN          NaN
# 4                                                NaN         NaN          NaN
# 5  Year in which countries have partially or comp...         NaN          NaN
# 6                                                NaN         NaN          NaN
# 7                                                NaN         NaN          NaN
# 8                                                NaN         NaN          NaN
# 9                                               1928         NaN          NaN

# %%
# Repositionner la ligne d'en-tête
df = pd.read_excel(source, header=6)
# https://stackoverflow.com/a/51794989
# Supprimez d'abord toutes les colonnes (axe=1) sans valeurs
df = df.dropna(how="all", axis=1)
# Supprimer toutes les lignes (axe=0) sans valeurs
df = df.dropna(how="all", axis=0).reset_index(drop=True)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1  \
# 0                HDI rank        NaN
# 1                     NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN
# 3                       1    Iceland
# 4                       2     Norway
# 5                       3  Australia
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0  Intentional homicidesa                 (per 10...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                  1        NaN
# 4                                                0.8        NaN
# 5                                                1.3        NaN
#
#                       Unnamed: 5 Unnamed: 6  \
# 0              Prison population        NaN
# 1  Total                   2007d        NaN
# 2                            NaN        NaN
# 3                            119        NaN
# 4                           3048        NaN
# 5                          25353        NaN
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                                NaN        NaN
# 1  (per 100,000 people)                        2007d        NaN
# 2                                                NaN        NaN
# 3                                                 40        NaN
# 4                                                 66        NaN
# 5                                                126        NaN
#
#                                           Unnamed: 9 Unnamed: 10  \
# 0                                                NaN         NaN
# 1  Female                         (% of total)   ...         NaN
# 2                                                NaN         NaN
# 3                                                  6         NaN
# 4                                                  5         NaN
# 5                                                  7         NaN
#
#   Year in which countries have partially or completely abolished the death penaltyb  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979
# 5                                               1985
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN

# %%
columns = []
for c in df.columns:
    # Pour chaque colonne, obtenir les valeurs des 5 premières lignes
    # puis conservez toutes les chaînes (c'est-à-dire excluez-les si elles sont nulles) et ajoutez-les en colonne
    columns.append([str(v) for v in df[c][:5] if pd.notnull(v)])
columns
# Out:
# [['HDI rank', 'HIGH HUMAN DEVELOPMENT', '1', '2'],
#  ['Iceland', 'Norway'],
#  ['Intentional homicidesa                 (per 100,000 people)                         2000-04c',
#   '1',
#   '0.8'],
#  [],
#  ['Prison population', 'Total                   2007d', '119', '3048'],
#  [],
#  ['(per 100,000 people)                        2007d', '40', '66'],
#  [],
#  ['Female                         (% of total)             2007e', '6', '5'],
#  [],
#  ['1928', '1979'],
#  []]

# %%
columns = [
    "HDI rank",
    "Country",
    "Intentional homicidesa                 (per 100,000 people)                         2000-04c",
    "Reference 1",
    "Prison population     Total                   2007d",
    "Reference 2",
    "Prison population     (per 100,000 people)                        2007d",
    "Reference 3",
    "Prison population     Female                         (% of total)             2007e",
    "Reference 4,
    "Year in which countries have partially or completely abolished the death penaltyb",
    "Reference 5"
]
# Réinitialiser les colonnes des cadres de données
df.columns = columns
# Supprimer les lignes qui contenaient les informations dont nous n'avons plus besoin
# et réinitialiser l'index
# np.arange(5) crée un tableau = [0, 1, 2, 3, 4, 5]
df = df.drop(np.arange(5), axis=0).reset_index(drop=True)
df.head(10)
# Out:
#   HDI rank     Country Reference 1  \
# 0       43   Lithuania         9.4
# 1       44     Estonia         6.8
# 2       45      Latvia         8.6
# 3       46     Uruguay         5.6
# 4       47     Croatia         1.8
# 5       48  Costa Rica         6.2
# 6       49     Bahamas        15.9
# 7       50  Seychelles         7.4
# 8       51        Cuba          ..
# 9       52      Mexico          13
#
#   Intentional homicidesa                 (per 100,000 people)                         2000-04c  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                  f
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Reference 2 Prison population     Total                   2007d Reference 3  \
# 0        8124                                                NaN          240
# 1        4463                                                NaN          333
# 2        6676                                                NaN          292
# 3        6947                                                NaN          193
# 4        3594                                                NaN           81
# 5        7782                                                NaN          181
# 6        1500                                                NaN          462
# 7         193                                                NaN          239
# 8       55000                                                NaN          487
# 9      214450                                                NaN          196
#
#   Prison population     (per 100,000 people)                        2007d  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Reference 4  \
# 0           3
# 1           4
# 2           6
# 3           6
# 4           5
# 5           7
# 6           2
# 7           8
# 8          ..
# 9           5
#
#   Prison population     Female                         (% of total)             2007e  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Reference 5  \
# 0        1998
# 1        1998
# 2        1999
# 3        1907
# 4        1990
# 5        1877
# 6          ..
# 7        1993
# 8          ..
# 9        2005
#
#   Year in which countries have partially or completely abolished the death penaltyb
# 0                                                NaN
# 1                                                NaN
# 2                                                  h
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                  g
# 7                                                NaN
# 8                                                  g
# 9                                                NaN

# %%
columns
# Out:
# ['HDI rank',
#  'Country',
#  'Intentional homicidesa                 (per 100,000 people)                         2000-04c',
#  'Reference 1',
#  'Prison population     Total                   2007d',
#  'Reference 2',
#  'Prison population     (per 100,000 people)                        2007d',
#  'Reference 3',
#  'Reference 4',
#  'Prison population     Female                         (% of total)             2007e',
#  'Reference 5',
#  'Year in which countries have partially or completely abolished the death penaltyb']
