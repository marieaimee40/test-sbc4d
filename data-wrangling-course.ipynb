# %% [markdown]
# Importons Deux modules avec import et Renommons les en utilisant le terme as :
#
# import pandas as pd
#
#
#
# import numpy as np

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Nous commençons par importer le fichier Excel.
#
#
# Dans pandas, une feuille de calcul est appelée dataframe, ou df en abrégé.

# %%
df = pd.read_excel("HDR 2007-2008 Table 27.xlsx")
df.head(12)
# Out:
#                 Unnamed: 0 Unnamed: 1                       Unnamed: 2  \
# 0                      NaN        NaN  … protecting personal security…
# 1     27 Crime and justice        NaN                              NaN
# 2                      NaN        NaN                              NaN
# 3                      NaN        NaN                              NaN
# 4                      NaN        NaN                              NaN
# 5                      NaN        NaN                              NaN
# 6                 HDI rank        NaN                              NaN
# 7                      NaN        NaN                              NaN
# 8   HIGH HUMAN DEVELOPMENT        NaN                              NaN
# 9                        1    Iceland                              NaN
# 10                       2     Norway                              NaN
# 11                       3  Australia                              NaN
#
#                                            Unnamed: 3 Unnamed: 4  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6   Intentional homicidesa                 (per 10...        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                                   1        NaN
# 10                                                0.8        NaN
# 11                                                1.3        NaN
#
#                        Unnamed: 5 Unnamed: 6  \
# 0                             NaN        NaN
# 1                             NaN        NaN
# 2                             NaN        NaN
# 3                             NaN        NaN
# 4                             NaN        NaN
# 5                             NaN        NaN
# 6               Prison population        NaN
# 7   Total                   2007d        NaN
# 8                             NaN        NaN
# 9                             119        NaN
# 10                           3048        NaN
# 11                          25353        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7   (per 100,000 people)                        2007d        NaN
# 8                                                 NaN        NaN
# 9                                                  40        NaN
# 10                                                 66        NaN
# 11                                                126        NaN
#
#                                            Unnamed: 9 Unnamed: 10  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7   Female                         (% of total)   ...         NaN
# 8                                                 NaN         NaN
# 9                                                   6         NaN
# 10                                                  5         NaN
# 11                                                  7         NaN
#
#                                           Unnamed: 11 Unnamed: 12  Unnamed: 13
# 0                                                 NaN         NaN          NaN
# 1                                                 NaN         NaN          NaN
# 2                                                 NaN         NaN          NaN
# 3                                                 NaN         NaN          NaN
# 4                                                 NaN         NaN          NaN
# 5   Year in which countries have partially or comp...         NaN          NaN
# 6                                                 NaN         NaN          NaN
# 7                                                 NaN         NaN          NaN
# 8                                                 NaN         NaN          NaN
# 9                                                1928         NaN          NaN
# 10                                               1979         NaN          NaN
# 11                                               1985         NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   186 non-null    object
#  1   Unnamed: 1   177 non-null    object
#  2   Unnamed: 2   1 non-null      object
#  3   Unnamed: 3   178 non-null    object
#  4   Unnamed: 4   22 non-null     object
#  5   Unnamed: 5   179 non-null    object
#  6   Unnamed: 6   13 non-null     object
#  7   Unnamed: 7   178 non-null    object
#  8   Unnamed: 8   13 non-null     object
#  9   Unnamed: 9   178 non-null    object
#  10  Unnamed: 10  3 non-null      object
#  11  Unnamed: 11  178 non-null    object
#  12  Unnamed: 12  101 non-null    object
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), object(13)
# memory usage: 11.6+ KB

# %% [markdown]
# 1. Repositionner la ligne d'en-tête
#
# 2. Supprimez d'abord toutes les colonnes (axe=1) sans valeurs
#
# 3. Supprimer toutes les lignes (axe=0) sans valeurs

# %%
df = pd.read_excel("HDR 2007-2008 Table 27.xlsx", header=6)
df = df.dropna(how="all", axis=1)
df = df.dropna(how="all", axis=0).reset_index(drop=True)
df.head(6)
# Out:
#                Unnamed: 0 Unnamed: 1  \
# 0                HDI rank        NaN
# 1                     NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN
# 3                       1    Iceland
# 4                       2     Norway
# 5                       3  Australia
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0  Intentional homicidesa                 (per 10...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                  1        NaN
# 4                                                0.8        NaN
# 5                                                1.3        NaN
#
#                       Unnamed: 5 Unnamed: 6  \
# 0              Prison population        NaN
# 1  Total                   2007d        NaN
# 2                            NaN        NaN
# 3                            119        NaN
# 4                           3048        NaN
# 5                          25353        NaN
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                                NaN        NaN
# 1  (per 100,000 people)                        2007d        NaN
# 2                                                NaN        NaN
# 3                                                 40        NaN
# 4                                                 66        NaN
# 5                                                126        NaN
#
#                                           Unnamed: 9 Unnamed: 10  \
# 0                                                NaN         NaN
# 1  Female                         (% of total)   ...         NaN
# 2                                                NaN         NaN
# 3                                                  6         NaN
# 4                                                  5         NaN
# 5                                                  7         NaN
#
#   Year in which countries have partially or completely abolished the death penaltyb  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979
# 5                                               1985
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Year in which countries have partially or completely abolished the death penaltyb',
#        'Unnamed: 12'],
#       dtype='object')

# %%
df.tail(30)
# Out:
#                                             Unnamed: 0  \
# 156                                                153
# 157                                                154
# 158                                                155
# 159                              LOW HUMAN DEVELOPMENT
# 160                                                156
# 161                                                157
# 162                                                158
# 163                                                159
# 164                                                160
# 165                                                161
# 166                                                162
# 167                                                163
# 168                                                164
# 169                                                165
# 170                                                166
# 171                                                167
# 172                                                168
# 173                                                169
# 174                                                170
# 175                                                171
# 176                                                172
# 177                                                173
# 178                                                174
# 179                                                175
# 180                                                176
# 181                                                177
# 182                                              NOTES
# 183                                               \n\n
# 184  a. Because of differences in the legal definit...
# 185  SOURCES\nColumn 1: UNODC 2007. \nColumns 2–4: ...
#
#                              Unnamed: 1 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 156                               Yemen          4        NaN      14000
# 157                              Uganda        7.4        NaN      26126
# 158                              Gambia         ..        NaN        450
# 159                                 NaN        NaN        NaN        NaN
# 160                             Senegal         ..        NaN       5360
# 161                             Eritrea         ..        NaN         ..
# 162                             Nigeria        1.5          f      40444
# 163       Tanzania (United Republic of)        7.5          f      43911
# 164                              Guinea         ..        NaN       3070
# 165                              Rwanda          8          f      67000
# 166                              Angola         ..        NaN       6008
# 167                               Benin         ..        NaN       5834
# 168                              Malawi         ..        NaN       9656
# 169                              Zambia        8.1        NaN      14347
# 170                       Côte d'Ivoire        4.1        NaN       9274
# 171                             Burundi         ..        NaN       7969
# 172  Congo (Democratic Republic of the)         ..        NaN      30000
# 173                            Ethiopia         ..        NaN      65000
# 174                                Chad         ..        NaN       3416
# 175            Central African Republic         ..        NaN       4168
# 176                          Mozambique         ..        NaN      10000
# 177                                Mali         ..        NaN       4407
# 178                               Niger         ..        NaN       5709
# 179                       Guinea-Bissau         ..        NaN         ..
# 180                        Burkina Faso         ..        NaN       2800
# 181                        Sierra Leone         ..        NaN       1740
# 182                                 NaN        NaN        NaN        NaN
# 183                                 NaN        NaN        NaN        NaN
# 184                                 NaN        NaN        NaN        NaN
# 185                                 NaN        NaN        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 156          f         83          f         ..           l
# 157        NaN         95        NaN          3         NaN
# 158        NaN         32        NaN          1         NaN
# 159        NaN        NaN        NaN        NaN         NaN
# 160        NaN         54        NaN          4         NaN
# 161        NaN         ..        NaN         ..         NaN
# 162        NaN         30        NaN          2         NaN
# 163        NaN        113        NaN          3         NaN
# 164        NaN         37        NaN          2         NaN
# 165          f        691        f,j          3         NaN
# 166        NaN         44        NaN          3         NaN
# 167        NaN         75        NaN          4         NaN
# 168        NaN         74        NaN          1         NaN
# 169        NaN        120        NaN          3         NaN
# 170          f         49          f          2         NaN
# 171        NaN        106        NaN          3         NaN
# 172        NaN         57        NaN          3         NaN
# 173        NaN         92        NaN         ..         NaN
# 174        NaN         35        NaN          2         NaN
# 175        NaN        110        NaN         ..         NaN
# 176        NaN         51        NaN          6         NaN
# 177        NaN         33        NaN          2         NaN
# 178        NaN         46        NaN          3         NaN
# 179        NaN         ..        NaN         ..         NaN
# 180        NaN         23        NaN          1         NaN
# 181        NaN         32        NaN         ..         NaN
# 182        NaN        NaN        NaN        NaN         NaN
# 183        NaN        NaN        NaN        NaN         NaN
# 184        NaN        NaN        NaN        NaN         NaN
# 185        NaN        NaN        NaN        NaN         NaN
#
#     Year in which countries have partially or completely abolished the death penaltyb  \
# 156                                                 ..
# 157                                                 ..
# 158                                               1981
# 159                                                NaN
# 160                                               2004
# 161                                                 ..
# 162                                                 ..
# 163                                                 ..
# 164                                                 ..
# 165                                                 ..
# 166                                               1992
# 167                                               1987
# 168                                               1992
# 169                                                 ..
# 170                                               2000
# 171                                                 ..
# 172                                                 ..
# 173                                                 ..
# 174                                                 ..
# 175                                               1981
# 176                                               1990
# 177                                               1980
# 178                                               1976
# 179                                               1993
# 180                                               1988
# 181                                                 ..
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
#
#     Unnamed: 12
# 156           g
# 157           g
# 158           i
# 159         NaN
# 160         NaN
# 161           g
# 162           g
# 163           g
# 164           g
# 165           g
# 166         NaN
# 167           i
# 168           i
# 169           g
# 170         NaN
# 171           g
# 172           g
# 173           g
# 174           g
# 175           i
# 176         NaN
# 177           i
# 178           i
# 179         NaN
# 180           i
# 181           g
# 182         NaN
# 183         NaN
# 184         NaN
# 185         NaN

# %%
#Déposer les lignes du bas des données que nous voulons conserver, jusqu'à la fin (défini comme len(dt))
df = df.drop(np.arange(182,len(df)), axis=0).reset_index(drop=True)

# %%
len(df)
# Out:
# 182

# %%
np.arange(182,len(df))
# Out:
# array([], dtype=int32)

# %%
np.arange(1,4)
# Out:
# array([1, 2, 3])

# %%
df.tail()
# Out:
#     Unnamed: 0     Unnamed: 1 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 177        173           Mali         ..        NaN       4407        NaN
# 178        174          Niger         ..        NaN       5709        NaN
# 179        175  Guinea-Bissau         ..        NaN         ..        NaN
# 180        176   Burkina Faso         ..        NaN       2800        NaN
# 181        177   Sierra Leone         ..        NaN       1740        NaN
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 177         33        NaN          2         NaN
# 178         46        NaN          3         NaN
# 179         ..        NaN         ..         NaN
# 180         23        NaN          1         NaN
# 181         32        NaN         ..         NaN
#
#     Year in which countries have partially or completely abolished the death penaltyb  \
# 177                                               1980
# 178                                               1976
# 179                                               1993
# 180                                               1988
# 181                                                 ..
#
#     Unnamed: 12
# 177           i
# 178           i
# 179         NaN
# 180           i
# 181           g

# %%
df = df.dropna(how="all", axis=1)

# %%
df
# Out:
#                  Unnamed: 0     Unnamed: 1  \
# 0                  HDI rank            NaN
# 1                       NaN            NaN
# 2    HIGH HUMAN DEVELOPMENT            NaN
# 3                         1        Iceland
# 4                         2         Norway
# ..                      ...            ...
# 177                     173           Mali
# 178                     174          Niger
# 179                     175  Guinea-Bissau
# 180                     176   Burkina Faso
# 181                     177   Sierra Leone
#
#                                             Unnamed: 3 Unnamed: 4  \
# 0    Intentional homicidesa                 (per 10...        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                    1        NaN
# 4                                                  0.8        NaN
# ..                                                 ...        ...
# 177                                                 ..        NaN
# 178                                                 ..        NaN
# 179                                                 ..        NaN
# 180                                                 ..        NaN
# 181                                                 ..        NaN
#
#                         Unnamed: 5 Unnamed: 6  \
# 0                Prison population        NaN
# 1    Total                   2007d        NaN
# 2                              NaN        NaN
# 3                              119        NaN
# 4                             3048        NaN
# ..                             ...        ...
# 177                           4407        NaN
# 178                           5709        NaN
# 179                             ..        NaN
# 180                           2800        NaN
# 181                           1740        NaN
#
#                                             Unnamed: 7 Unnamed: 8  \
# 0                                                  NaN        NaN
# 1    (per 100,000 people)                        2007d        NaN
# 2                                                  NaN        NaN
# 3                                                   40        NaN
# 4                                                   66        NaN
# ..                                                 ...        ...
# 177                                                 33        NaN
# 178                                                 46        NaN
# 179                                                 ..        NaN
# 180                                                 23        NaN
# 181                                                 32        NaN
#
#                                             Unnamed: 9 Unnamed: 10  \
# 0                                                  NaN         NaN
# 1    Female                         (% of total)   ...         NaN
# 2                                                  NaN         NaN
# 3                                                    6         NaN
# 4                                                    5         NaN
# ..                                                 ...         ...
# 177                                                  2         NaN
# 178                                                  3         NaN
# 179                                                 ..         NaN
# 180                                                  1         NaN
# 181                                                 ..         NaN
#
#     Year in which countries have partially or completely abolished the death penaltyb  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 1928
# 4                                                 1979
# ..                                                 ...
# 177                                               1980
# 178                                               1976
# 179                                               1993
# 180                                               1988
# 181                                                 ..
#
#     Unnamed: 12
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 177           i
# 178           i
# 179         NaN
# 180           i
# 181           g
#
# [182 rows x 12 columns]

# %%
df.size
# Out:
# 2184

# %%
MA = ["HDI RANK",
    "COUNTRY",
    "Intentional homicides                 (per 100,000 people)                         2000-04",
    "Reference 1",
    "Prison population     Total                   2007",
    "Reference 2",
    "Prison population     (per 100,000 people)                        2007",
    "Reference 3",
    "Prison population     Female                         (% of total)             2007",
    "Reference 4",
    "Year in which countries have partially or completely abolished the death penalty",
    "Reference 5"
]

# %%
len(MA)
# Out:
# 12

# %%
len(df.columns)
# Out:
# 12

# %%
df.columns=MA
df.columns
# Out:
# Index(['HDI RANK', 'COUNTRY',
#        'Intentional homicides                 (per 100,000 people)                         2000-04',
#        'Reference 1', 'Prison population     Total                   2007',
#        'Reference 2',
#        'Prison population     (per 100,000 people)                        2007',
#        'Reference 3',
#        'Prison population     Female                         (% of total)             2007',
#        'Reference 4',
#        'Year in which countries have partially or completely abolished the death penalty',
#        'Reference 5'],
#       dtype='object')

# %%
df.head()
# Out:
#                  HDI RANK  COUNTRY  \
# 0                HDI rank      NaN
# 1                     NaN      NaN
# 2  HIGH HUMAN DEVELOPMENT      NaN
# 3                       1  Iceland
# 4                       2   Norway
#
#   Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0  Intentional homicidesa                 (per 10...
# 1                                                NaN
# 2                                                NaN
# 3                                                  1
# 4                                                0.8
#
#   Reference 1 Prison population     Total                   2007 Reference 2  \
# 0         NaN                                  Prison population         NaN
# 1         NaN                      Total                   2007d         NaN
# 2         NaN                                                NaN         NaN
# 3         NaN                                                119         NaN
# 4         NaN                                               3048         NaN
#
#   Prison population     (per 100,000 people)                        2007  \
# 0                                                NaN
# 1  (per 100,000 people)                        2007d
# 2                                                NaN
# 3                                                 40
# 4                                                 66
#
#   Reference 3  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Prison population     Female                         (% of total)             2007  \
# 0                                                NaN
# 1  Female                         (% of total)   ...
# 2                                                NaN
# 3                                                  6
# 4                                                  5
#
#   Reference 4  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Year in which countries have partially or completely abolished the death penalty  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979
#
#   Reference 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df = df.drop(np.arange(0,2), axis=0).reset_index(drop=True)
df.head()
# Out:
#                  HDI RANK    COUNTRY  \
# 0  HIGH HUMAN DEVELOPMENT        NaN
# 1                       1    Iceland
# 2                       2     Norway
# 3                       3  Australia
# 4                       4     Canada
#
#   Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0                                                NaN
# 1                                                  1
# 2                                                0.8
# 3                                                1.3
# 4                                                1.9
#
#   Reference 1 Prison population     Total                   2007 Reference 2  \
# 0         NaN                                                NaN         NaN
# 1         NaN                                                119         NaN
# 2         NaN                                               3048         NaN
# 3         NaN                                              25353         NaN
# 4         NaN                                              34096           f
#
#   Prison population     (per 100,000 people)                        2007  \
# 0                                                NaN
# 1                                                 40
# 2                                                 66
# 3                                                126
# 4                                                107
#
#   Reference 3  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4           f
#
#   Prison population     Female                         (% of total)             2007  \
# 0                                                NaN
# 1                                                  6
# 2                                                  5
# 3                                                  7
# 4                                                  5
#
#   Reference 4  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Year in which countries have partially or completely abolished the death penalty  \
# 0                                                NaN
# 1                                               1928
# 2                                               1979
# 3                                               1985
# 4                                               1998
#
#   Reference 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df["HDI RANK"].index
df[df["HDI RANK"].isin(hdi_categories)].index
# Out:
# Int64Index([0, 71, 157], dtype='int64')

# %%
df = df.drop(df[df["HDI RANK"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)

# %%
df.loc[:, "HDI RANK"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 172    173
# 173    174
# 174    175
# 175    176
# 176    177
# Name: HDI RANK, Length: 177, dtype: object

# %%
df.loc[:, "HDI NIVEAU_DEV"] = np.where(df["HDI RANK"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI RANK"] < 71,
                                              "HIGH HUMAN DEVELOPMENT",
                                              "MEDIUM HUMAN DEVELOPMENT"
                                              
                                             )
                                    )
df.sort_values(by="HDI RANK", inplace=True)
df.head()
# Out:
#   HDI RANK    COUNTRY  \
# 0        1    Iceland
# 1        2     Norway
# 2        3  Australia
# 3        4     Canada
# 4        5    Ireland
#
#   Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0                                                  1
# 1                                                0.8
# 2                                                1.3
# 3                                                1.9
# 4                                                0.9
#
#   Reference 1 Prison population     Total                   2007 Reference 2  \
# 0         NaN                                                119         NaN
# 1         NaN                                               3048         NaN
# 2         NaN                                              25353         NaN
# 3         NaN                                              34096           f
# 4         NaN                                               3080         NaN
#
#   Prison population     (per 100,000 people)                        2007  \
# 0                                                 40
# 1                                                 66
# 2                                                126
# 3                                                107
# 4                                                 72
#
#   Reference 3  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3           f
# 4         NaN
#
#   Prison population     Female                         (% of total)             2007  \
# 0                                                  6
# 1                                                  5
# 2                                                  7
# 3                                                  5
# 4                                                  4
#
#   Reference 4  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Year in which countries have partially or completely abolished the death penalty  \
# 0                                               1928
# 1                                               1979
# 2                                               1985
# 3                                               1998
# 4                                               1990
#
#   Reference 5          HDI NIVEAU_DEV
# 0         NaN  HIGH HUMAN DEVELOPMENT
# 1         NaN  HIGH HUMAN DEVELOPMENT
# 2         NaN  HIGH HUMAN DEVELOPMENT
# 3         NaN  HIGH HUMAN DEVELOPMENT
# 4         NaN  HIGH HUMAN DEVELOPMENT
