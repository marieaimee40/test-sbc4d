# %% [markdown]
# Importons Deux modules avec import et Renommons les en utilisant le terme as :
#
# import pandas as pd
#
#
#
# import numpy as np

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Nous commençons par importer le fichier Excel.
#
#
# Dans pandas, une feuille de calcul est appelée dataframe, ou df en abrégé.
#
#
# Affichons les 12 premières lignes de notre dataframe

# %%
df = pd.read_excel("HDR 2007-2008 Table 27.xlsx")
df.head(12)
# Out:
#                 Unnamed: 0 Unnamed: 1                       Unnamed: 2  \
# 0                      NaN        NaN  … protecting personal security…
# 1     27 Crime and justice        NaN                              NaN
# 2                      NaN        NaN                              NaN
# 3                      NaN        NaN                              NaN
# 4                      NaN        NaN                              NaN
# 5                      NaN        NaN                              NaN
# 6                 HDI rank        NaN                              NaN
# 7                      NaN        NaN                              NaN
# 8   HIGH HUMAN DEVELOPMENT        NaN                              NaN
# 9                        1    Iceland                              NaN
# 10                       2     Norway                              NaN
# 11                       3  Australia                              NaN
#
#                                            Unnamed: 3 Unnamed: 4  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6   Intentional homicidesa                 (per 10...        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                                   1        NaN
# 10                                                0.8        NaN
# 11                                                1.3        NaN
#
#                        Unnamed: 5 Unnamed: 6  \
# 0                             NaN        NaN
# 1                             NaN        NaN
# 2                             NaN        NaN
# 3                             NaN        NaN
# 4                             NaN        NaN
# 5                             NaN        NaN
# 6               Prison population        NaN
# 7   Total                   2007d        NaN
# 8                             NaN        NaN
# 9                             119        NaN
# 10                           3048        NaN
# 11                          25353        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7   (per 100,000 people)                        2007d        NaN
# 8                                                 NaN        NaN
# 9                                                  40        NaN
# 10                                                 66        NaN
# 11                                                126        NaN
#
#                                            Unnamed: 9 Unnamed: 10  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7   Female                         (% of total)   ...         NaN
# 8                                                 NaN         NaN
# 9                                                   6         NaN
# 10                                                  5         NaN
# 11                                                  7         NaN
#
#                                           Unnamed: 11 Unnamed: 12  Unnamed: 13
# 0                                                 NaN         NaN          NaN
# 1                                                 NaN         NaN          NaN
# 2                                                 NaN         NaN          NaN
# 3                                                 NaN         NaN          NaN
# 4                                                 NaN         NaN          NaN
# 5   Year in which countries have partially or comp...         NaN          NaN
# 6                                                 NaN         NaN          NaN
# 7                                                 NaN         NaN          NaN
# 8                                                 NaN         NaN          NaN
# 9                                                1928         NaN          NaN
# 10                                               1979         NaN          NaN
# 11                                               1985         NaN          NaN

# %%
df.tail(30) # Renvoie à afficher les 30 dernières lignes de notre dataframe
# Out:
#                                             Unnamed: 0  \
# 167                                                157
# 168                                                158
# 169                                                159
# 170                                                160
# 171                                                161
# 172                                                162
# 173                                                163
# 174                                                164
# 175                                                165
# 176                                                166
# 177                                                167
# 178                                                168
# 179                                                169
# 180                                                170
# 181                                                171
# 182                                                172
# 183                                                173
# 184                                                174
# 185                                                175
# 186                                                176
# 187                                                177
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                              NOTES
# 193                                               \n\n
# 194  a. Because of differences in the legal definit...
# 195                                                NaN
# 196  SOURCES\nColumn 1: UNODC 2007. \nColumns 2–4: ...
#
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 167                             Eritrea        NaN         ..        NaN
# 168                             Nigeria        NaN        1.5          f
# 169       Tanzania (United Republic of)        NaN        7.5          f
# 170                              Guinea        NaN         ..        NaN
# 171                              Rwanda        NaN          8          f
# 172                              Angola        NaN         ..        NaN
# 173                               Benin        NaN         ..        NaN
# 174                              Malawi        NaN         ..        NaN
# 175                              Zambia        NaN        8.1        NaN
# 176                       Côte d'Ivoire        NaN        4.1        NaN
# 177                             Burundi        NaN         ..        NaN
# 178  Congo (Democratic Republic of the)        NaN         ..        NaN
# 179                            Ethiopia        NaN         ..        NaN
# 180                                Chad        NaN         ..        NaN
# 181            Central African Republic        NaN         ..        NaN
# 182                          Mozambique        NaN         ..        NaN
# 183                                Mali        NaN         ..        NaN
# 184                               Niger        NaN         ..        NaN
# 185                       Guinea-Bissau        NaN         ..        NaN
# 186                        Burkina Faso        NaN         ..        NaN
# 187                        Sierra Leone        NaN         ..        NaN
# 188                                 NaN        NaN        NaN        NaN
# 189                                 NaN        NaN        NaN        NaN
# 190                                 NaN        NaN        NaN        NaN
# 191                                 NaN        NaN        NaN        NaN
# 192                                 NaN        NaN        NaN        NaN
# 193                                 NaN        NaN        NaN        NaN
# 194                                 NaN        NaN        NaN        NaN
# 195                                 NaN        NaN        NaN        NaN
# 196                                 NaN        NaN        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 167         ..        NaN         ..        NaN         ..         NaN
# 168      40444        NaN         30        NaN          2         NaN
# 169      43911        NaN        113        NaN          3         NaN
# 170       3070        NaN         37        NaN          2         NaN
# 171      67000          f        691        f,j          3         NaN
# 172       6008        NaN         44        NaN          3         NaN
# 173       5834        NaN         75        NaN          4         NaN
# 174       9656        NaN         74        NaN          1         NaN
# 175      14347        NaN        120        NaN          3         NaN
# 176       9274          f         49          f          2         NaN
# 177       7969        NaN        106        NaN          3         NaN
# 178      30000        NaN         57        NaN          3         NaN
# 179      65000        NaN         92        NaN         ..         NaN
# 180       3416        NaN         35        NaN          2         NaN
# 181       4168        NaN        110        NaN         ..         NaN
# 182      10000        NaN         51        NaN          6         NaN
# 183       4407        NaN         33        NaN          2         NaN
# 184       5709        NaN         46        NaN          3         NaN
# 185         ..        NaN         ..        NaN         ..         NaN
# 186       2800        NaN         23        NaN          1         NaN
# 187       1740        NaN         32        NaN         ..         NaN
# 188        NaN        NaN        NaN        NaN        NaN         NaN
# 189        NaN        NaN        NaN        NaN        NaN         NaN
# 190        NaN        NaN        NaN        NaN        NaN         NaN
# 191        NaN        NaN        NaN        NaN        NaN         NaN
# 192        NaN        NaN        NaN        NaN        NaN         NaN
# 193        NaN        NaN        NaN        NaN        NaN         NaN
# 194        NaN        NaN        NaN        NaN        NaN         NaN
# 195        NaN        NaN        NaN        NaN        NaN         NaN
# 196        NaN        NaN        NaN        NaN        NaN         NaN
#
#     Unnamed: 11 Unnamed: 12  Unnamed: 13
# 167          ..           g          NaN
# 168          ..           g          NaN
# 169          ..           g          NaN
# 170          ..           g          NaN
# 171          ..           g          NaN
# 172        1992         NaN          NaN
# 173        1987           i          NaN
# 174        1992           i          NaN
# 175          ..           g          NaN
# 176        2000         NaN          NaN
# 177          ..           g          NaN
# 178          ..           g          NaN
# 179          ..           g          NaN
# 180          ..           g          NaN
# 181        1981           i          NaN
# 182        1990         NaN          NaN
# 183        1980           i          NaN
# 184        1976           i          NaN
# 185        1993         NaN          NaN
# 186        1988           i          NaN
# 187          ..           g          NaN
# 188         NaN         NaN          NaN
# 189         NaN         NaN          NaN
# 190         NaN         NaN          NaN
# 191         NaN         NaN          NaN
# 192         NaN         NaN          NaN
# 193         NaN         NaN          NaN
# 194         NaN         NaN          NaN
# 195         NaN         NaN          NaN
# 196         NaN         NaN          NaN

# %%
#Sauvegarder les notes et sources dans des dataframes qui sont df_NOTES , df_SOURCES

df_NOTES = df.iloc[192:195,]
df_SOURCES = df.iloc[196:,]

df_NOTES = df_NOTES.dropna(how = 'any', axis = 1).reset_index(drop=True)

df_SOURCES = df_SOURCES.dropna(how = 'any', axis = 1).reset_index(drop=True)

# %%
df_NOTES
# Out:
#                                           Unnamed: 0
# 0                                              NOTES
# 1                                               \n\n
# 2  a. Because of differences in the legal definit...

# %%
df_SOURCES
# Out:
#                                           Unnamed: 0
# 0  SOURCES\nColumn 1: UNODC 2007. \nColumns 2–4: ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   186 non-null    object
#  1   Unnamed: 1   177 non-null    object
#  2   Unnamed: 2   1 non-null      object
#  3   Unnamed: 3   178 non-null    object
#  4   Unnamed: 4   22 non-null     object
#  5   Unnamed: 5   179 non-null    object
#  6   Unnamed: 6   13 non-null     object
#  7   Unnamed: 7   178 non-null    object
#  8   Unnamed: 8   13 non-null     object
#  9   Unnamed: 9   178 non-null    object
#  10  Unnamed: 10  3 non-null      object
#  11  Unnamed: 11  178 non-null    object
#  12  Unnamed: 12  101 non-null    object
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), object(13)
# memory usage: 11.6+ KB

# %% [markdown]
# 1. Repositionner la ligne d'en-tête et supprimer les lignes qui ne nous servent pas
#
# 2. Supprimez d'abord toutes les colonnes (axe=1) sans valeurs
#
# 3. Supprimer toutes les lignes (axe=0) sans valeurs

# %%
df = pd.read_excel("HDR 2007-2008 Table 27.xlsx", header=6)
df = df.dropna(how="all", axis=1)
df = df.dropna(how="all", axis=0).reset_index(drop=True)
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1  \
# 0                HDI rank        NaN
# 1                     NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN
# 3                       1    Iceland
# 4                       2     Norway
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0  Intentional homicidesa                 (per 10...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                  1        NaN
# 4                                                0.8        NaN
#
#                       Unnamed: 5 Unnamed: 6  \
# 0              Prison population        NaN
# 1  Total                   2007d        NaN
# 2                            NaN        NaN
# 3                            119        NaN
# 4                           3048        NaN
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                                NaN        NaN
# 1  (per 100,000 people)                        2007d        NaN
# 2                                                NaN        NaN
# 3                                                 40        NaN
# 4                                                 66        NaN
#
#                                           Unnamed: 9 Unnamed: 10  \
# 0                                                NaN         NaN
# 1  Female                         (% of total)   ...         NaN
# 2                                                NaN         NaN
# 3                                                  6         NaN
# 4                                                  5         NaN
#
#   Year in which countries have partially or completely abolished the death penaltyb  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.columns #nous permet de connaitre tous les éléments qui sont dans les colonnes
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Year in which countries have partially or completely abolished the death penaltyb',
#        'Unnamed: 12'],
#       dtype='object')

# %%
#Déposer les lignes du bas des données que nous voulons conserver, jusqu'à la fin (défini comme len(dt))
df = df.drop(np.arange(182,len(df)), axis=0).reset_index(drop=True)

# %%
len(df) #nous permet d'avoir le nombre d'éléments dans une liste
# Out:
# 182

# %%
np.arange(182,len(df)) #Renvoie des valeurs régulièrement espacées dans un intervalle donné.
# Out:
# array([], dtype=int32)

# %%
np.arange(1,4)
# Out:
# array([1, 2, 3])

# %%
df.tail(25) #Renvoie la liste des 25 derniers éléments de notre dataframe
# Out:
#                 Unnamed: 0                          Unnamed: 1 Unnamed: 3  \
# 157                    154                              Uganda        7.4
# 158                    155                              Gambia         ..
# 159  LOW HUMAN DEVELOPMENT                                 NaN        NaN
# 160                    156                             Senegal         ..
# 161                    157                             Eritrea         ..
# 162                    158                             Nigeria        1.5
# 163                    159       Tanzania (United Republic of)        7.5
# 164                    160                              Guinea         ..
# 165                    161                              Rwanda          8
# 166                    162                              Angola         ..
# 167                    163                               Benin         ..
# 168                    164                              Malawi         ..
# 169                    165                              Zambia        8.1
# 170                    166                       Côte d'Ivoire        4.1
# 171                    167                             Burundi         ..
# 172                    168  Congo (Democratic Republic of the)         ..
# 173                    169                            Ethiopia         ..
# 174                    170                                Chad         ..
# 175                    171            Central African Republic         ..
# 176                    172                          Mozambique         ..
# 177                    173                                Mali         ..
# 178                    174                               Niger         ..
# 179                    175                       Guinea-Bissau         ..
# 180                    176                        Burkina Faso         ..
# 181                    177                        Sierra Leone         ..
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 157        NaN      26126        NaN         95        NaN          3
# 158        NaN        450        NaN         32        NaN          1
# 159        NaN        NaN        NaN        NaN        NaN        NaN
# 160        NaN       5360        NaN         54        NaN          4
# 161        NaN         ..        NaN         ..        NaN         ..
# 162          f      40444        NaN         30        NaN          2
# 163          f      43911        NaN        113        NaN          3
# 164        NaN       3070        NaN         37        NaN          2
# 165          f      67000          f        691        f,j          3
# 166        NaN       6008        NaN         44        NaN          3
# 167        NaN       5834        NaN         75        NaN          4
# 168        NaN       9656        NaN         74        NaN          1
# 169        NaN      14347        NaN        120        NaN          3
# 170        NaN       9274          f         49          f          2
# 171        NaN       7969        NaN        106        NaN          3
# 172        NaN      30000        NaN         57        NaN          3
# 173        NaN      65000        NaN         92        NaN         ..
# 174        NaN       3416        NaN         35        NaN          2
# 175        NaN       4168        NaN        110        NaN         ..
# 176        NaN      10000        NaN         51        NaN          6
# 177        NaN       4407        NaN         33        NaN          2
# 178        NaN       5709        NaN         46        NaN          3
# 179        NaN         ..        NaN         ..        NaN         ..
# 180        NaN       2800        NaN         23        NaN          1
# 181        NaN       1740        NaN         32        NaN         ..
#
#     Unnamed: 10  \
# 157         NaN
# 158         NaN
# 159         NaN
# 160         NaN
# 161         NaN
# 162         NaN
# 163         NaN
# 164         NaN
# 165         NaN
# 166         NaN
# 167         NaN
# 168         NaN
# 169         NaN
# 170         NaN
# 171         NaN
# 172         NaN
# 173         NaN
# 174         NaN
# 175         NaN
# 176         NaN
# 177         NaN
# 178         NaN
# 179         NaN
# 180         NaN
# 181         NaN
#
#     Year in which countries have partially or completely abolished the death penaltyb  \
# 157                                                 ..
# 158                                               1981
# 159                                                NaN
# 160                                               2004
# 161                                                 ..
# 162                                                 ..
# 163                                                 ..
# 164                                                 ..
# 165                                                 ..
# 166                                               1992
# 167                                               1987
# 168                                               1992
# 169                                                 ..
# 170                                               2000
# 171                                                 ..
# 172                                                 ..
# 173                                                 ..
# 174                                                 ..
# 175                                               1981
# 176                                               1990
# 177                                               1980
# 178                                               1976
# 179                                               1993
# 180                                               1988
# 181                                                 ..
#
#     Unnamed: 12
# 157           g
# 158           i
# 159         NaN
# 160         NaN
# 161           g
# 162           g
# 163           g
# 164           g
# 165           g
# 166         NaN
# 167           i
# 168           i
# 169           g
# 170         NaN
# 171           g
# 172           g
# 173           g
# 174           g
# 175           i
# 176         NaN
# 177           i
# 178           i
# 179         NaN
# 180           i
# 181           g

# %%
df = df.dropna(how="all", axis=1)

# %%
df.head()
# Out:
#                Unnamed: 0 Unnamed: 1  \
# 0                HDI rank        NaN
# 1                     NaN        NaN
# 2  HIGH HUMAN DEVELOPMENT        NaN
# 3                       1    Iceland
# 4                       2     Norway
#
#                                           Unnamed: 3 Unnamed: 4  \
# 0  Intentional homicidesa                 (per 10...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                  1        NaN
# 4                                                0.8        NaN
#
#                       Unnamed: 5 Unnamed: 6  \
# 0              Prison population        NaN
# 1  Total                   2007d        NaN
# 2                            NaN        NaN
# 3                            119        NaN
# 4                           3048        NaN
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                                NaN        NaN
# 1  (per 100,000 people)                        2007d        NaN
# 2                                                NaN        NaN
# 3                                                 40        NaN
# 4                                                 66        NaN
#
#                                           Unnamed: 9 Unnamed: 10  \
# 0                                                NaN         NaN
# 1  Female                         (% of total)   ...         NaN
# 2                                                NaN         NaN
# 3                                                  6         NaN
# 4                                                  5         NaN
#
#   Year in which countries have partially or completely abolished the death penaltyb  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.size
# Out:
# 2184

# %%
MA = ["HDI RANK",
    "COUNTRY",
    "Intentional homicides                 (per 100,000 people)                         2000-04",
    "Reference 1",
    "Prison population     Total                   2007",
    "Reference 2",
    "Prison population     (per 100,000 people)                        2007",
    "Reference 3",
    "Prison population     Female                         (% of total)             2007",
    "Reference 4",
    "Year in which countries have partially or completely abolished the death penalty",
    "Reference 5"
]

# %%
len(MA)
# Out:
# 12

# %%
len(df.columns)
# Out:
# 12

# %%
df.columns=MA
df.columns
# Out:
# Index(['HDI RANK', 'COUNTRY',
#        'Intentional homicides                 (per 100,000 people)                         2000-04',
#        'Reference 1', 'Prison population     Total                   2007',
#        'Reference 2',
#        'Prison population     (per 100,000 people)                        2007',
#        'Reference 3',
#        'Prison population     Female                         (% of total)             2007',
#        'Reference 4',
#        'Year in which countries have partially or completely abolished the death penalty',
#        'Reference 5'],
#       dtype='object')

# %%
df.head()
# Out:
#                  HDI RANK  COUNTRY  \
# 0                HDI rank      NaN
# 1                     NaN      NaN
# 2  HIGH HUMAN DEVELOPMENT      NaN
# 3                       1  Iceland
# 4                       2   Norway
#
#   Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0  Intentional homicidesa                 (per 10...
# 1                                                NaN
# 2                                                NaN
# 3                                                  1
# 4                                                0.8
#
#   Reference 1 Prison population     Total                   2007 Reference 2  \
# 0         NaN                                  Prison population         NaN
# 1         NaN                      Total                   2007d         NaN
# 2         NaN                                                NaN         NaN
# 3         NaN                                                119         NaN
# 4         NaN                                               3048         NaN
#
#   Prison population     (per 100,000 people)                        2007  \
# 0                                                NaN
# 1  (per 100,000 people)                        2007d
# 2                                                NaN
# 3                                                 40
# 4                                                 66
#
#   Reference 3  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Prison population     Female                         (% of total)             2007  \
# 0                                                NaN
# 1  Female                         (% of total)   ...
# 2                                                NaN
# 3                                                  6
# 4                                                  5
#
#   Reference 4  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Year in which countries have partially or completely abolished the death penalty  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979
#
#   Reference 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
#Supprimer toutes les references qui se trouvent dans notre dataframe
df.drop(['Reference 1','Reference 2','Reference 3','Reference 4','Reference 5'],axis='columns',inplace=True)
df.head()
# Out:
#                  HDI RANK  COUNTRY  \
# 0                HDI rank      NaN
# 1                     NaN      NaN
# 2  HIGH HUMAN DEVELOPMENT      NaN
# 3                       1  Iceland
# 4                       2   Norway
#
#   Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0  Intentional homicidesa                 (per 10...
# 1                                                NaN
# 2                                                NaN
# 3                                                  1
# 4                                                0.8
#
#   Prison population     Total                   2007  \
# 0                                  Prison population
# 1                      Total                   2007d
# 2                                                NaN
# 3                                                119
# 4                                               3048
#
#   Prison population     (per 100,000 people)                        2007  \
# 0                                                NaN
# 1  (per 100,000 people)                        2007d
# 2                                                NaN
# 3                                                 40
# 4                                                 66
#
#   Prison population     Female                         (% of total)             2007  \
# 0                                                NaN
# 1  Female                         (% of total)   ...
# 2                                                NaN
# 3                                                  6
# 4                                                  5
#
#   Year in which countries have partially or completely abolished the death penalty
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               1928
# 4                                               1979

# %%
# Supprimer les lignes qui contenaient les informations dont nous n'avons plus besoin
# et réinitialiser l'index
# np.arange(2) crée un tableau = [0, 1, 2, 3, 4, 5]
df = df.drop(np.arange(0,2), axis=0).reset_index(drop=True)
df.head(20)
# Out:
#                   HDI RANK         COUNTRY  \
# 0   HIGH HUMAN DEVELOPMENT             NaN
# 1                        1         Iceland
# 2                        2          Norway
# 3                        3       Australia
# 4                        4          Canada
# 5                        5         Ireland
# 6                        6          Sweden
# 7                        7     Switzerland
# 8                        8           Japan
# 9                        9     Netherlands
# 10                      10          France
# 11                      11         Finland
# 12                      12   United States
# 13                      13           Spain
# 14                      14         Denmark
# 15                      15         Austria
# 16                      16  United Kingdom
# 17                      17         Belgium
# 18                      18      Luxembourg
# 19                      19     New Zealand
#
#    Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0                                                 NaN
# 1                                                   1
# 2                                                 0.8
# 3                                                 1.3
# 4                                                 1.9
# 5                                                 0.9
# 6                                                 2.4
# 7                                                 2.9
# 8                                                 0.5
# 9                                                   1
# 10                                                1.6
# 11                                                2.8
# 12                                                5.6
# 13                                                1.2
# 14                                                0.8
# 15                                                0.8
# 16                                                2.1
# 17                                                1.5
# 18                                                0.9
# 19                                                1.3
#
#    Prison population     Total                   2007  \
# 0                                                 NaN
# 1                                                 119
# 2                                                3048
# 3                                               25353
# 4                                               34096
# 5                                                3080
# 6                                                7450
# 7                                                6111
# 8                                               79055
# 9                                               21013
# 10                                              52009
# 11                                               3954
# 12                                            2186230
# 13                                              64215
# 14                                               4198
# 15                                               8766
# 16                                              88458
# 17                                               9597
# 18                                                768
# 19                                               7620
#
#    Prison population     (per 100,000 people)                        2007  \
# 0                                                 NaN
# 1                                                  40
# 2                                                  66
# 3                                                 126
# 4                                                 107
# 5                                                  72
# 6                                                  82
# 7                                                  83
# 8                                                  62
# 9                                                 128
# 10                                                 85
# 11                                                 75
# 12                                                738
# 13                                                145
# 14                                                 77
# 15                                                105
# 16                                                124
# 17                                                 91
# 18                                                167
# 19                                                186
#
#    Prison population     Female                         (% of total)             2007  \
# 0                                                 NaN
# 1                                                   6
# 2                                                   5
# 3                                                   7
# 4                                                   5
# 5                                                   4
# 6                                                   5
# 7                                                   5
# 8                                                   6
# 9                                                   9
# 10                                                  4
# 11                                                  6
# 12                                                  9
# 13                                                  8
# 14                                                  5
# 15                                                  5
# 16                                                  6
# 17                                                  4
# 18                                                  5
# 19                                                  6
#
#    Year in which countries have partially or completely abolished the death penalty
# 0                                                 NaN
# 1                                                1928
# 2                                                1979
# 3                                                1985
# 4                                                1998
# 5                                                1990
# 6                                                1972
# 7                                                1992
# 8                                                  ..
# 9                                                1982
# 10                                               1981
# 11                                               1972
# 12                                                 ..
# 13                                               1995
# 14                                               1978
# 15                                               1968
# 16                                               1998
# 17                                               1996
# 18                                               1979
# 19                                               1989

# %%
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df["HDI RANK"].index
df[df["HDI RANK"].isin(hdi_categories)].index
# Out:
# Int64Index([0, 71, 157], dtype='int64')

# %%
df = df.drop(df[df["HDI RANK"].isin(hdi_categories)].index, axis=0).reset_index(drop=True)

# %%
df.loc[:, "HDI RANK"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 172    173
# 173    174
# 174    175
# 175    176
# 176    177
# Name: HDI RANK, Length: 177, dtype: object

# %%
df.loc[:, "HDI NIVEAU_DEV"] = np.where(df["HDI RANK"] > 155,
                                     "LOW HUMAN DEVELOPMENT",
                                     np.where(df["HDI RANK"] < 71,
                                              "HIGH HUMAN DEVELOPMENT",
                                              "MEDIUM HUMAN DEVELOPMENT"
                                              
                                             )
                                    )
df.sort_values(by="HDI RANK", inplace=True)
df.head()
# Out:
#   HDI RANK    COUNTRY  \
# 0        1    Iceland
# 1        2     Norway
# 2        3  Australia
# 3        4     Canada
# 4        5    Ireland
#
#   Intentional homicides                 (per 100,000 people)                         2000-04  \
# 0                                                  1
# 1                                                0.8
# 2                                                1.3
# 3                                                1.9
# 4                                                0.9
#
#   Prison population     Total                   2007  \
# 0                                                119
# 1                                               3048
# 2                                              25353
# 3                                              34096
# 4                                               3080
#
#   Prison population     (per 100,000 people)                        2007  \
# 0                                                 40
# 1                                                 66
# 2                                                126
# 3                                                107
# 4                                                 72
#
#   Prison population     Female                         (% of total)             2007  \
# 0                                                  6
# 1                                                  5
# 2                                                  7
# 3                                                  5
# 4                                                  4
#
#   Year in which countries have partially or completely abolished the death penalty  \
# 0                                               1928
# 1                                               1979
# 2                                               1985
# 3                                               1998
# 4                                               1990
#
#            HDI NIVEAU_DEV
# 0  HIGH HUMAN DEVELOPMENT
# 1  HIGH HUMAN DEVELOPMENT
# 2  HIGH HUMAN DEVELOPMENT
# 3  HIGH HUMAN DEVELOPMENT
# 4  HIGH HUMAN DEVELOPMENT

# %%
df.tail(30)
# Out:
#     HDI RANK                             COUNTRY  \
# 147      148                               Kenya
# 148      149                            Djibouti
# 149      150                         Timor-Leste
# 150      151                            Zimbabwe
# 151      152                                Togo
# 152      153                               Yemen
# 153      154                              Uganda
# 154      155                              Gambia
# 155      156                             Senegal
# 156      157                             Eritrea
# 157      158                             Nigeria
# 158      159       Tanzania (United Republic of)
# 159      160                              Guinea
# 160      161                              Rwanda
# 161      162                              Angola
# 162      163                               Benin
# 163      164                              Malawi
# 164      165                              Zambia
# 165      166                       Côte d'Ivoire
# 166      167                             Burundi
# 167      168  Congo (Democratic Republic of the)
# 168      169                            Ethiopia
# 169      170                                Chad
# 170      171            Central African Republic
# 171      172                          Mozambique
# 172      173                                Mali
# 173      174                               Niger
# 174      175                       Guinea-Bissau
# 175      176                        Burkina Faso
# 176      177                        Sierra Leone
#
#     Intentional homicides                 (per 100,000 people)                         2000-04  \
# 147                                                 ..
# 148                                                 ..
# 149                                                 ..
# 150                                                8.4
# 151                                                 ..
# 152                                                  4
# 153                                                7.4
# 154                                                 ..
# 155                                                 ..
# 156                                                 ..
# 157                                                1.5
# 158                                                7.5
# 159                                                 ..
# 160                                                  8
# 161                                                 ..
# 162                                                 ..
# 163                                                 ..
# 164                                                8.1
# 165                                                4.1
# 166                                                 ..
# 167                                                 ..
# 168                                                 ..
# 169                                                 ..
# 170                                                 ..
# 171                                                 ..
# 172                                                 ..
# 173                                                 ..
# 174                                                 ..
# 175                                                 ..
# 176                                                 ..
#
#     Prison population     Total                   2007  \
# 147                                              47036
# 148                                                384
# 149                                                320
# 150                                              18033
# 151                                               3200
# 152                                              14000
# 153                                              26126
# 154                                                450
# 155                                               5360
# 156                                                 ..
# 157                                              40444
# 158                                              43911
# 159                                               3070
# 160                                              67000
# 161                                               6008
# 162                                               5834
# 163                                               9656
# 164                                              14347
# 165                                               9274
# 166                                               7969
# 167                                              30000
# 168                                              65000
# 169                                               3416
# 170                                               4168
# 171                                              10000
# 172                                               4407
# 173                                               5709
# 174                                                 ..
# 175                                               2800
# 176                                               1740
#
#     Prison population     (per 100,000 people)                        2007  \
# 147                                                130
# 148                                                 61
# 149                                                 41
# 150                                                139
# 151                                                 65
# 152                                                 83
# 153                                                 95
# 154                                                 32
# 155                                                 54
# 156                                                 ..
# 157                                                 30
# 158                                                113
# 159                                                 37
# 160                                                691
# 161                                                 44
# 162                                                 75
# 163                                                 74
# 164                                                120
# 165                                                 49
# 166                                                106
# 167                                                 57
# 168                                                 92
# 169                                                 35
# 170                                                110
# 171                                                 51
# 172                                                 33
# 173                                                 46
# 174                                                 ..
# 175                                                 23
# 176                                                 32
#
#     Prison population     Female                         (% of total)             2007  \
# 147                                                  4
# 148                                                 ..
# 149                                                (.)
# 150                                                  3
# 151                                                  2
# 152                                                 ..
# 153                                                  3
# 154                                                  1
# 155                                                  4
# 156                                                 ..
# 157                                                  2
# 158                                                  3
# 159                                                  2
# 160                                                  3
# 161                                                  3
# 162                                                  4
# 163                                                  1
# 164                                                  3
# 165                                                  2
# 166                                                  3
# 167                                                  3
# 168                                                 ..
# 169                                                  2
# 170                                                 ..
# 171                                                  6
# 172                                                  2
# 173                                                  3
# 174                                                 ..
# 175                                                  1
# 176                                                 ..
#
#     Year in which countries have partially or completely abolished the death penalty  \
# 147                                               1987
# 148                                               1995
# 149                                               1999
# 150                                                 ..
# 151                                               1960
# 152                                                 ..
# 153                                                 ..
# 154                                               1981
# 155                                               2004
# 156                                                 ..
# 157                                                 ..
# 158                                                 ..
# 159                                                 ..
# 160                                                 ..
# 161                                               1992
# 162                                               1987
# 163                                               1992
# 164                                                 ..
# 165                                               2000
# 166                                                 ..
# 167                                                 ..
# 168                                                 ..
# 169                                                 ..
# 170                                               1981
# 171                                               1990
# 172                                               1980
# 173                                               1976
# 174                                               1993
# 175                                               1988
# 176                                                 ..
#
#                HDI NIVEAU_DEV
# 147  MEDIUM HUMAN DEVELOPMENT
# 148  MEDIUM HUMAN DEVELOPMENT
# 149  MEDIUM HUMAN DEVELOPMENT
# 150  MEDIUM HUMAN DEVELOPMENT
# 151  MEDIUM HUMAN DEVELOPMENT
# 152  MEDIUM HUMAN DEVELOPMENT
# 153  MEDIUM HUMAN DEVELOPMENT
# 154  MEDIUM HUMAN DEVELOPMENT
# 155     LOW HUMAN DEVELOPMENT
# 156     LOW HUMAN DEVELOPMENT
# 157     LOW HUMAN DEVELOPMENT
# 158     LOW HUMAN DEVELOPMENT
# 159     LOW HUMAN DEVELOPMENT
# 160     LOW HUMAN DEVELOPMENT
# 161     LOW HUMAN DEVELOPMENT
# 162     LOW HUMAN DEVELOPMENT
# 163     LOW HUMAN DEVELOPMENT
# 164     LOW HUMAN DEVELOPMENT
# 165     LOW HUMAN DEVELOPMENT
# 166     LOW HUMAN DEVELOPMENT
# 167     LOW HUMAN DEVELOPMENT
# 168     LOW HUMAN DEVELOPMENT
# 169     LOW HUMAN DEVELOPMENT
# 170     LOW HUMAN DEVELOPMENT
# 171     LOW HUMAN DEVELOPMENT
# 172     LOW HUMAN DEVELOPMENT
# 173     LOW HUMAN DEVELOPMENT
# 174     LOW HUMAN DEVELOPMENT
# 175     LOW HUMAN DEVELOPMENT
# 176     LOW HUMAN DEVELOPMENT

# %%
#Exportons notre fichier sur le format CSV
df.to_csv('HDR 2007-2008 Table 27.csv',index=False) 

#Enregistrons notre fichier en excell avec plusieurs feuilles Table 23 Notes et Sources
with pd.ExcelWriter('HDR 2007-2008 Table 27_KONENATH.xlsx') as writer:
    df.to_excel(writer, sheet_name = 'Données finales', index = False)
    df_NOTES.to_excel(writer, sheet_name = 'NOTES', index = False)
    df_SOURCES.to_excel(writer, sheet_name = 'SOURCES', index = False)
